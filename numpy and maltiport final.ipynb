# %%
hobby_counts = df['Hobbyist'].value_counts()
plt.figure(figsize=(6,6))
explode = [0] * len(hobby_counts) # Initialize explode with zeros, assuming no slices are exploded by default
plt.pie(
    hobby_counts,
    labels=hobby_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['skyblue', 'orange'],
    explode=explode,
    shadow=True,
    textprops={'fontsize':12},
    wedgeprops={'edgecolor':'black', 'linewidth':1}
)
plt.title("Hobbylist Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2111/404349635.py in <cell line: 0>()
# ----> 1 hobby_counts = df['Hobbyist'].value_counts()
#       2 plt.figure(figsize=(6,6))
#       3 explode = [0] * len(hobby_counts) # Initialize explode with zeros, assuming no slices are exploded by default
#       4 plt.pie(
#       5     hobby_counts,
#
# NameError: name 'df' is not defined

# %%
hobby_counts = df['Hobbyist'].value_counts()
plt.figure(figsize=(6,6))
explode = [0] * len(hobby_counts) # Initialize explode with zeros, assuming no slices are exploded by default
plt.pie(
    hobby_counts,
    labels=hobby_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['gold', 'lightgreen'], # Added colors
    explode=explode, # Added explode
    shadow=True,
    textprops={'fontsize':12},
    wedgeprops={'edgecolor':'black', 'linewidth':1}
)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("Hobbylist Distribution(Donut Chart)")
plt.show()

# %%
import seaborn as sns

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
corr_matrix = numeric_df.corr()
corr_matrix

# %%
# 0.00-0.19 =very weak
# 0.20-0.39 =weak
# 0.40-0.59 = moderate
# 0.60-0.79 = strong
# 0.80-1.00 = very strong

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2111/296579140.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(10,8))
# ----> 3 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
#       4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# NameError: name 'sns' is not defined

# %%
pip install squarify

# %%
from matplotlib import text

import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('titanic')
class_counts = df['pclass'].value_counts()
plt.figure(figsize=(8,6))
squarify.plot(sizes=class_counts, label=class_counts.index, alpha=0.8)
text_kwargs={
    'fontsize':14,
    'fontweight':'bold',
    'color':'black'
}
bar_kwargs={
    'edgecolor':'black',
    'linewidth':2
}
plt.title("Passenger Distribution by Class", fontdict=text_kwargs)
plt.axis('off')
plt.title("Passenger Distribution by Class")
plt.axis('off')
plt.show()

# %%
from ipywidgets import Label
df['FamilySize'] = df['sibsp'] + df['parch']
plt.figure('figsize=(8,6)')
plt.scatter(
    df['age'],
    df['fare'],
    s=df['FamilySize']*50,
    alpha=0.5,
    c=df['pclass'],
    edgecolors='black',
    linewidths=1.5,
    marker='o',
    label='Passengers'

)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title("Bubble Chart:Age vs Fare")

# %%
#**Violin PLot**

# %%
import seaborn as sns
from pandas.core.reshape import tile
plt.figure(figsize=(8,6))
sns.violinplot(x='pclass', y='age', data=df)
plt.title('Age Distribution by Passenger Class')
plt.show()
