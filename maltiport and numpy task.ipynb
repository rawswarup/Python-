# %%
def add(x) :
  return x + 5

print(add(10))
# Out:
# 15

# %%
add = lambda x: x+5
print(add(10))
# Out:
# 15

# %%
import pandas as pd
ages = pd.Series([20, 25, 30, 35])
ages.apply(lambda x: x+5)
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
country_group = df.groupby('housing_median_age')
country_python = country_group['median_income'].apply(lambda x: x.mean())
country_python
# Out:
# housing_median_age
# 1.0     4.756800
# 2.0     5.074237
# 3.0     5.572013
# 4.0     5.196055
# 5.0     4.732460
# 6.0     4.463901
# 7.0     4.368441
# 8.0     4.412988
# 9.0     4.357513
# 10.0    4.126004
# 11.0    4.029663
# 12.0    4.003208
# 13.0    4.145092
# 14.0    4.148454
# 15.0    4.003953
# 16.0    4.288458
# 17.0    3.929201
# 18.0    3.954591
# 19.0    3.833244
# 20.0    3.749984
# 21.0    3.870417
# 22.0    3.941335
# 23.0    3.963371
# 24.0    3.921026
# 25.0    4.135890
# 26.0    4.071895
# 27.0    3.859375
# 28.0    3.813176
# 29.0    3.633556
# 30.0    3.580732
# 31.0    3.619995
# 32.0    3.800399
# 33.0    3.862161
# 34.0    3.959488
# 35.0    3.909391
# 36.0    3.973530
# 37.0    3.684131
# 38.0    3.463225
# 39.0    3.395865
# 40.0    3.432734
# 41.0    3.149125
# 42.0    3.447088
# 43.0    3.238897
# 44.0    3.507043
# 45.0    3.739467
# 46.0    3.357832
# 47.0    3.278638
# 48.0    3.526261
# 49.0    3.547657
# 50.0    3.472372
# 51.0    3.670503
# ...

# %%
country_total = country_group.size().rename('total_count')
country_python_sorted = country_python.sort_values(ascending=False)
python_df = pd.concat([country_python, country_total], axis='columns')
python_df
# Out:
#                     median_income  total_count
# housing_median_age
# 1.0                      4.756800            2
# 2.0                      5.074237           49
# 3.0                      5.572013           46
# 4.0                      5.196055          161
# 5.0                      4.732460          199
# 6.0                      4.463901          129
# 7.0                      4.368441          151
# 8.0                      4.412988          178
# 9.0                      4.357513          172
# 10.0                     4.126004          226
# 11.0                     4.029663          208
# 12.0                     4.003208          192
# 13.0                     4.145092          249
# 14.0                     4.148454          347
# 15.0                     4.003953          416
# 16.0                     4.288458          635
# 17.0                     3.929201          576
# 18.0                     3.954591          478
# ...

# %%
python_df.rename(columns={'count':Total})

# %%
python_df['Percent_MedianIncome_Per_TotalCount'] = (python_df['median_income'] / python_df['total_count']) * 100
python_df
# Out:
#                     median_income  total_count  \
# housing_median_age
# 1.0                      4.756800            2
# 2.0                      5.074237           49
# 3.0                      5.572013           46
# 4.0                      5.196055          161
# 5.0                      4.732460          199
# 6.0                      4.463901          129
# 7.0                      4.368441          151
# 8.0                      4.412988          178
# 9.0                      4.357513          172
# 10.0                     4.126004          226
# 11.0                     4.029663          208
# 12.0                     4.003208          192
# 13.0                     4.145092          249
# 14.0                     4.148454          347
# 15.0                     4.003953          416
# 16.0                     4.288458          635
# 17.0                     3.929201          576
# 18.0                     3.954591          478
# ...
